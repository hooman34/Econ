# %%
import investpy
import pandas as pd
from fredapi import Fred
import json
from matplotlib import pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import quandl
from datetime import date
from utils.utils import *
from plotly.subplots import make_subplots

with open('keys/keys.json', 'r') as key_file:
    keys = json.load(key_file)
    
with open('utils/index_codes.json', 'r') as indx:
    index_codes = json.load(indx)

# %%
tsry10 = fred_fred(index_codes['Fred']["Treasury 10y"], 
                 column_name='Treasury 10y', observation_start='01/01/2012')

# %%
tsry10_diff = tsry10.copy()
tsry10_diff['Treasury 10y'] = tsry10_diff['Treasury 10y'].diff()

# %%
vtv = investing_api('etf', 'VTV', '01/01/2012', '20/03/2021')
vot = investing_api('etf', 'VOT', '01/01/2012', '20/03/2021')

# %%
trace1 = go.Scatter(x=tsry10['date'],
                    y=tsry10['Treasury 10y'],
                    name='Treasury 10y')
trace2 = go.Scatter(x=vtv['Date'],
                    y=vtv['Close'],
                    name='vanguard value')

fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(trace1)
fig.add_trace(trace2, secondary_y=True)
# Out:
# <div>                            <div id="561e13f1-2966-4f65-aedf-bb86cbcce036" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("561e13f1-2966-4f65-aedf-bb86cbcce036")) {                    Plotly.newPlot(                        "561e13f1-2966-4f65-aedf-bb86cbcce036",                        [{"name": "Treasury 10y", "type": "scatter", "x": ["2012-01-02T00:00:00", "2012-01-03T00:00:00", "2012-01-04T00:00:00", "2012-01-05T00:00:00", "2012-01-06T00:00:00", "2012-01-09T00:00:00", "2012-01-10T00:00:00", "2012-01-11T00:00:00", "2012-01-12T00:00:00", "2012-01-13T00:00:00", "2012-01-16T00:00:00", "2012-01-17T00:00:00", "2012-01-18T00:00:00", "2012-01-19T00:00:00", "2012-01-20T00:00:00", "2012-01-23T00:00:00", "2012-01-24T00:00:00", "2012-01-25T00:00:00", "20
# ...

# %%
trace1 = go.Scatter(x=vot['Date'],
                    y=vot['Close'],
                    name='vanguard growth')
trace2 = go.Scatter(x=vtv['Date'],
                    y=vtv['Close'],
                    name='vanguard value')

fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(trace1)
fig.add_trace(trace2, secondary_y=True)
# Out:
# <div>                            <div id="9b159b25-ae7e-4448-8fed-c1e68d50916c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b159b25-ae7e-4448-8fed-c1e68d50916c")) {                    Plotly.newPlot(                        "9b159b25-ae7e-4448-8fed-c1e68d50916c",                        [{"name": "vanguard growth", "type": "scatter", "x": ["2012-01-03T00:00:00", "2012-01-04T00:00:00", "2012-01-05T00:00:00", "2012-01-06T00:00:00", "2012-01-09T00:00:00", "2012-01-10T00:00:00", "2012-01-11T00:00:00", "2012-01-12T00:00:00", "2012-01-13T00:00:00", "2012-01-17T00:00:00", "2012-01-18T00:00:00", "2012-01-19T00:00:00", "2012-01-20T00:00:00", "2012-01-23T00:00:00", "2012-01-24T00:00:00", "2012-01-25T00:00:00", "2012-01-26T00:00:00", "2012-01-27T00:00:00", 
# ...

# %%
trace1 = go.Scatter(x=tsry10['date'],
                    y=tsry10['Treasury 10y'],
                    name='Treasury 10y')
trace2 = go.Scatter(x=vtv['Date'],
                    y=vtv['Close'],
                    name='vanguard value')

fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(trace1)
fig.add_trace(trace2, secondary_y=True)
# Out:
# <div>                            <div id="6f48ef85-a527-4f6d-9a4f-7ca7cec15072" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f48ef85-a527-4f6d-9a4f-7ca7cec15072")) {                    Plotly.newPlot(                        "6f48ef85-a527-4f6d-9a4f-7ca7cec15072",                        [{"name": "Treasury 10y", "type": "scatter", "x": ["2012-01-02T00:00:00", "2012-01-03T00:00:00", "2012-01-04T00:00:00", "2012-01-05T00:00:00", "2012-01-06T00:00:00", "2012-01-09T00:00:00", "2012-01-10T00:00:00", "2012-01-11T00:00:00", "2012-01-12T00:00:00", "2012-01-13T00:00:00", "2012-01-16T00:00:00", "2012-01-17T00:00:00", "2012-01-18T00:00:00", "2012-01-19T00:00:00", "2012-01-20T00:00:00", "2012-01-23T00:00:00", "2012-01-24T00:00:00", "2012-01-25T00:00:00", "20
# ...
